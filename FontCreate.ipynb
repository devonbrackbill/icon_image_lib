# %% [markdown]
# # Font Generation

# %%
! apt update
! apt install -y libcairo2-dev
! apt-get install ffmpeg libsm6 libxext6  -y
! pip install opencv-python
! pip install pandas
! pip install matplotlib
! pip install Pillow

# %%
import matplotlib.pyplot as plt
import string
import os
from PIL import Image
import cv2
import shutil
import json
import matplotlib

# %%
# import matplotlib.font_manager
# from IPython.core.display import HTML

# def make_html(fontname):
#     return "<p>{font}: <span style='font-family:{font}; font-size: 24px;'>{font}</p>".format(font=fontname)

# code = "\n".join([make_html(font) for font in sorted(set([f.name for f in matplotlib.font_manager.fontManager.ttflist]))])

# HTML("<div style='column-count: 2;'>{}</div>".format(code))

# %%
# font descriptions from here: https://danielgreene.com/2010/03/30/fonts-with-descriptions/

font_descriptions = {"Andale Monospaced": "is a highly legible monospaced font. Regular only.",
"Arial": "Monotype Drawing Office 1982. A contemporary sans serif design, Arial contains more humanist characteristics than many of its predecessors and as such is more in tune with the mood of the last decades of the twentieth century. The overall treatment of curves is softer and fuller than in most industrial-style sans serif faces. Terminal strokes are cut on the diagonal which helps to give the face a less mechanical appearance. Arial is an extremely versatile family of typefaces which can be used with equal success for text setting in reports, presentations, magazines etc, and for display use in newspapers, advertising and promotions. Regular, Italic, Bold, and Bold Italic. Contains common ligatures that are not apparent in the phrase File systems for affluent field offices.",

"Arial Black": "display use in newspapers, advertising and promotions. Regular only.",
"Arial Narrow": "…an extremely versatile family of typefaces which can be used with equal success for text setting in reports, presentations, magazines etc, and for display use in newspapers, advertising and promotions.",
# "Arial Rounded MT Bold": "…an extremely versatile family of typefaces which can be used with equal success for text setting in reports, presentations, magazines etc, and for display use in newspapers, advertising and promotions.",
"Arial Unicode MS": "This extended version of Monotype's Arial contains glyphs for all code points within The Unicode Standard, Version 2.1. Regular only. Contains typographical features such as common ligatures that are not apparent in the phrase File systems for affluent field offices.",

"Book Antigua": "This is a roman typeface based on pen-drawn letters of the Italian Renaissance. Because it is distinctive and gentle in appearance it can be used to give a document a different feel than is given by the more geometrical designs of most text faces. It is also useful for occasional lines, as in letter headings and compliments slips. Its beautiful italic has many uses of its own (italicization mine for demonstration purposes). Regular, Italic, Bold, and Bold Italic.",

"Bookman Old Style": "The origins of Bookman Old Style lie in the typeface called Oldstyle Antique, designed by A C Phemister circa 1858 for the Miller and Richard foundry in Edinburgh, Scotland. Many American foundries made versions of this type which eventually became known as Bookman. Monotype Bookman Old Style roman is based on earlier Lanston Monotype and ATF models. The italic has been re drawn following the style of the Oldstyle Antique italics of Miller and Richard. Although called 'Old Style', the near vertical stress of the face puts it into the transitional category. A legible and robust text face (italicization mine for demonstration purposes). Regular, Italic, Bold, Bold Italic.",

"Brush Script MT": "This heavy, informal script looks as though it was written with a brush because its lowercase letters join together. Use the uppercase letters primarily as initials, although you might find it interesting to use all CAPITALS of this typeface for some words (capitalization mine for demonstration purposes). Regular only.",

"Calibri":  "is a modern sans serif family with subtle roundings on stems and corners. It features real italics, Small Capitals, and multiple numeral sets. Its proportions allow high impact in tightly set lines of big and small text alike. Calibri's many curves and the new rasteriser team up in bigger sizes to reveal a warm and soft character (italicization and small capitalization mine for demonstration purposes). Regular, Italic, Bold, and Bold Italic. Contains other typographic features such as common ligatures apparent in the phrase File systems for affluent field offices.",

"Cambria": "has been designed for on-screen reading and to look good when printed at small sizes. It has very even spacing and proportions. Diagonal and vertical hairlines and serifs are relatively strong, while horizontal serifs are small and intend to emphasize stroke endings rather than stand out themselves. This principle is most noticeable in the italics where the lowercase characters are subdued in style to be at their best as elements of word-images. When Cambria is used for captions at sizes over 20 point, the inter-character spacing should be slightly reduced for best results. The design isn't just intended for business documents: The regular weight has been extended with a large set of math and science symbols. The Greek and Cyrillic has been designed under close supervision of an international team of experts, who aimed to set a historical new standard in multi-script type design (italicization mine for demonstration purposes). Regular, Italic, Bold, and Bold Italic. Contains Small Capitals and other typographic features such as common ligatures (barely) apparent in the phrase File systems for affluent field offices. (If you magnify the text you'll see that the ascender on the lowercase f before an o curves over farther beyond the crossbar than the f before an i.)",

"Candara": "is a casual humanist sans with verticals showing a graceful entasis on stems, high-branching arcades in the lowercase, large apertures in all open forms, and unique ogee curves on diagonals. The resultant texture is lively but not intrusive, and makes for afriendly and readable text. Regular, Italic, Bold, and Bold Italic. Contains Small Capitals and other typographical features such as common ligatures apparent in the phrase File systems for affluent field offices.",

"Consolas": "is aimed for use in programming environments and other circumstances where a monospaced font is specified. All characters have the same width, like old typewriters, making it a good choice for personal and business correspondence. The improved Windows font display allowed a design with proportions closer to normal text than traditional monospaced fonts like Courier. This allows for more comfortably reading of extended text on screen. OpenType features include hanging or lining numerals; slashed, dotted and normal zeros; and alternative shapes for a number of lowercase letters. The look of text can be tuned to personal taste by varying the number of bars and waves. Regular, Italic, Bold, and Bold Italic.",

"Constantia": "is a modulated wedge-serif typeface designed primarily for continuous text in both electronic and paper publishing. The design responds to the recent narrowing of the gap between screen readability and traditional print media, exploiting specific aspects of the most recent advances in ClearType rendering, such as sub-pixel positioning. The classic proportions of relatively small x-height and long extenders make Constantia ideal for book and journal publishing, while the slight squareness and open counters ensure that it remains legible even at small sizes. Regular, Italic, Bold, and Bold Italic. Contains Small Capitals and other typographical features such as common ligatures apparent in the phrase File systems for affluent field offices.",

"Corbel": "is designed to give an uncluttered and clean appearance on screen. The letter forms are open with soft, flowing curves. It is legible, clear and functional at small sizes. At larger sizes the detailing and style of the shapes is more apparent resulting in a modern sans serif type with a wide range of possible uses. Regular, Italic, Bold, and Bold Italic. Contains Small Capitals and other typographical features such as common ligatures apparent in the phrase File systems for affluent field offices.",

"Century Gothic": "A design based on Monotype 20th Century, which was drawn by Sol Hess between 1936 and 1947. Century Gothic maintains the basic design of 20th Century but has an enlarged 'x' height and has been modified to ensure satisfactory output from modern digital systems. The design is influenced by the geometric style sans serif faces which were popular during the 1920's and 30's. Useful for headlines and general display work and for small quantities of text, particularly in advertising. Regular, Italic, Bold, and Bold Italic.",

"Century Schoolbook": "Another member of the Century family which was based on Century Expanded. Designed to fulfill the need for a solid, legible face for printing schoolbooks. It is wider and heavier than Century Expanded, there is also less contrast between thick and thin strokes. First cut by Monotype in 1934 and based on versions from ATF and Lanston Monotype. The sturdy nature of this typeface, coupled with its inherent legibility, has made it a popular choice for setting books, newspapers and magazines. Regular, Italic, Bold, and Bold Italic.",

"Comic Sans MS": "Designed by Microsoft's Vincent Connare, this is a face based on the lettering from comic magazines. This casual but legible face has proved very popular with a wide variety of people. Regular and Bold.",

"Curlz MT": "Curlz was designed by Steve Matteson and Carl Crossgrove in 1995. For a unique, festive touch, add a little Curlz to posters, flyers, invitations, menus and tee shirts. Regular only.",

"Didot": "The Didot family were active as designers for about 100 years in the 18th and 19th centuries. They were printers, publishers, typeface designers, inventors and intellectuals. Around 1800 the Didot family owned the most important print shop and font foundry in France. Pierre Didot, the printer, published a document with the typefaces of his brother, Firmin Didot, the typeface designer.The strong clear forms of this alphabet display objective, rational characteristics and are representative of the time and philosophy of the Enlightenment. Adrian Frutiger's Didot is a sensitive interpretation of the French Modern Face Didot. Another model for this design is the Henriade, a historical printing of the original Didot from 1818. The font Didot gives text a classic and elegant feel. Regular, bold, and italic. Contains Small Capitals, lining numerals, and old-style numerals, and common ligatures apparent in the phrase File systems for affluent field offices.",

"Franklin Gothic Book & Franklin Gothic Medium": "Designed in 1902 by Morris Fuller Benton for the American Type Founders company, Franklin Gothic Book still reigns as one of the most-widely used sans serif typefaces. Originally issued in only one weight, the ATF version of Franklin Gothic was eventually expanded to include five additional weights, but no light or intermediate weights were ever developed. In 1979, under license from ATF, ITC developed four new weights in roman and italic: book, medium, demi and heavy. Designed by Victor Caruso, ITC's new weights matched the original face's characteristics, but featured a slightly enlarged lowercase x-height. ITC Franklin Gothic also features a slightly condensed lowercase a-z alphabet. In 1991, ITC commissioned the Font Bureau in Boston to create condensed, compressed and extra compressed versions of ITC Franklin Gothic, which increased the flexibility and usefulness of the design. Franklin Gothic Book: Regular and Italic; Franklin Gothic Medium: Regular and Italic.",

"Futura": "Paul Renner (1878-1956) was a painter, typographer, typeface designer and teacher. Between 1908 and 1917 he designed thousands of books for Munich publishers in a refined traditional style. In the early 1920s he began to support the modern styles of architecture and typography, becoming a leading proponent of the New Typography. Renner is best known for designing the typeface Futura, which became a standard tool for the New Typography, and remains a popular typeface today. Futura does give a restful, almost bland impression, which accords with Renner's objectives. Futura seems classical, not only due to the form of its capitals, but also to the open, wide forms of the geometrical small letters. The typeface relies on notions of classical, yet contemporary form, – harmony and evenness of texture. Thanks to the modern digital technology Futura lives on in a greater variety than ever, offering a wide choice of typographic solutions for contemporary design in the new millennium. Medium, Medium Italic, Condensed Medium, and Condensed Extra Bold. Contains common ligatures apparent in the phrase File systems for affluent field offices.",

"Garamond": "This typeface is based on roman types cut by Jean Jannon in 1615. Jannon followed the designs of Claude Garamond which had been cut in the previous century. Garamond's types were, in turn, based on those used by Aldus Manutius in 1495 and cut by Francesco Griffo. The italic is based on types cut in France circa 1557 by Robert Granjon. Garamond is a beautiful typeface with an air of informality which looks good in a wide range of applications. It works particularly well in books and lengthy text settings (italicization mine for demonstration purposes). Regular, Italic, and Bold.",

"Gill Sans": "Monotype Type Drawing Office 1928. Gill studied under the renowned calligrapher, Edward Johnston, the designer of the London Underground sans serif typeface. This influenced Gill who later experimented with sans serif designs, and in due course produced a set of capital letters. These became Monotype series 231, produced in 1923, and the forerunner of the extensive Gill Sans range now available. A twentieth century sans serif that has a simplicity of form which does not reject traditional forms and proportions, and gives the face a humanist feel. The lighter weights are highly readable in text and suitable for magazine and book work, whereas the heavier weights are best used for display in advertising, packaging, and labels. Regular, Light, Italic, Light Italic, Bold, and Bold Italic. Contains common ligatures apparent in the phrase File systems for affluent field offices.",

"Gill Sans Ultra Bold": "…used for display in advertising, packaging, and labels. Regular only.",

"Helvetica Neue": "Helvetica (Latin for Swiss) has the objective and functional style which was associated with Swiss typography in the 1950s and 1960s. It is perfect for international correspondence: no ornament, no emotion, just clear presentation of information. Helvetica is still one of the best selling sans-serif fonts. Regular, Medium, Light, UltraLight, Italic, UltraLight Italic, Bold, Bold Italic, Condensed Bold, and Condensed Black. Contains common ligatures not apparent in the phrase File systems for affluent field offices.",

"Impact": "1965. Designed for the Stephenson Blake type foundry. A very heavy, narrow, sans serif face intended for use in newspapers, for headlines and in advertisements. Aptly named, this face has a very large 'x' height with short ascenders and descenders. Regular only.",

"Menlo": "is based upon the Open Source font Bitstream Vera and the public domain font Deja Vu. Bitstream Vera is a trademark of Bitstream, Inc., designed by Jim Lyles. Menlo is based upon the Open Source font Bitstream Vera and the public domain font Deja Vu. Bitstream Vera is a trademark of Bitstream, Inc., designed by Jim Lyles. Regular, Italic, Bold, and Bold Italic. Contains common ligatures apparent in the phrase. File systems for affluent field offices.",

"Perpetua": "A sensitive adaptation of a style of letter that had been popularized for monumental work in stone by Eric Gill. Large scale drawings by Gill were given to Charles Malin, a Parisian punch-cutter, and his hand cut punches were the basis for the font issued by Monotype. The incised quality of Perpetua will lend distinction to any work compatible with its serenity. First used in a private translation called The Passion of Perpetua and Felicity; the italic was originally called Felicity. Widely used as a text face in quality books, Perpetua is also very popular in advertising and display work. Regular, Italic, Bold, and Bold Italic.",

"Perpetua Titling": "popular in advertising and display work. Light & Bold.",

"Rockwell": "is a distinctive version of a geometric slab serif design, which has retained its popularity since its appearance in the 1930's. The slab serifs, or Egyptians, originated in the nineteenth century when they were used principally for display work. Rockwell is notable for its judiciously clipped slab serifs, and is given a particular sparkle by means of its angular terminals. In more recent years this style of typeface has been increasingly used for text setting where their even colour and visual impact can be fully exploited. Regular, Italic, Bold, and Bold Italic.",

"Rockwell Extra Bold": "used principally for display work. Regular only.",

"Stencil": "Stencil faces have been made for as long as people have been shipping wooden boxes. Most of the letterforms look a bit like a softer, bolder Clarendon before lines are cut through it to allow counters (those little spaces enclosed in 'a', 'b' and other letters) to remain as counters without becoming solid blobs. Consider this Stencil face a decorative font for limited use; a little goes a long way. Regular only.",

"Trebuchet": "…designed by Vincent Connare in 1996, is a humanist sans serif designed for easy screen readability. Trebuchet takes its inspiration from the sans serifs of the 1930s which had large x heights and round features intended to promote readability on signs. The typeface name is credited to a puzzle heard at Microsoft, where the question was asked, 'could you build a Trebuchet (a form of medieval catapult) to launch a person from the main campus to the consumer campus, and how?' The Trebuchet fonts are intended to be the vehicle that fires your messages across the Internet. Launch your message with a Trebuchet page. Regular, Italic, Bold, and Bold Italic.",

"Zapfino": "Today's digital font technology has allowed renowned type designer Hermann Zapf to realise a dream he first had more than fifty years ago: to create a fully calligraphic typeface. Regular only. Contains several typographical features including ligatures apparent in the phrase File systems for affluent field offices",

"Monotype Corsiva": "An italic typeface made in the style of the early Italian cursives, as exemplified by the work of the writing master Ludovico degli Arrighi in the sixteenth century. The capitals are of swash design, with characteristic flourishes, designed primarily for use as initial letters. Corsiva can be used for short text passages in advertising but is best used to add sparkle to invitations, greeting cards and menus, and to give a sense of occasion to certificates and awards. Regular only."
}

# %%
# available Matplotlib fonts
fonts_matplotlib = [f.name for f in matplotlib.font_manager.fontManager.ttflist]

# %%
# fonts in matplotlib that we have a description for:
fonts_to_use = [font for font in set(fonts_matplotlib) if font in font_descriptions.keys()]
fonts_to_use
# Out:
# ['Gill Sans',
#  'Zapfino',
#  'Didot',
#  'Brush Script MT',
#  'Arial Black',
#  'Helvetica Neue',
#  'Arial Unicode MS',
#  'Impact',
#  'Arial',
#  'Arial Narrow',
#  'Comic Sans MS',
#  'Futura',
#  'Rockwell',
#  'Menlo']

# %%
def setup_directories():
    # setup directories
    try:
        os.mkdir('res')
        print('created /res directory')
    except OSError:
        print("res/ already exists")
setup_directories()
# Out:
# res/ already exists

# %%
dir_raw_png = 'res/fonts-matplotlib-raw/'
dir_final_png = 'res/fonts-matplotlib-final/'
dir_final_class_png = 'res/fonts-matplotlib-class-final/'

try:
    os.mkdir(dir_raw_png)
except OSError:
    print("{} already exists".format(dir_final_png))

try:
    os.mkdir(dir_final_png)
except OSError:
    print("{} already exists".format(dir_final_png))

try:
    os.mkdir(dir_final_class_png)
except OSError:
    print("{} already exists".format(dir_final_class_png))

# %%
# plot each letter in each font in matplotlib:
for character in string.ascii_letters:
    for font in fonts_to_use:
        fig, ax = plt.subplots(figsize=(1, 1))
        #ax.text(1,2,"a", fontsize=12, ha="center")
        ax.text(0.5, 0.5, character, fontdict={'fontname': font, 'fontsize':60},
                ha='center', va='center', transform=ax.transAxes)
        ax.axis('off')
        prefix = 'lower' if character.islower() else 'upper'
        outfile = os.path.join(dir_raw_png, '{}-{}-{}.png'.format(font, prefix, character))
        plt.gcf().set_size_inches(1, 1)
        plt.savefig(outfile, bbox_inches='tight', pad_inches=0, dpi=512)
        # don't show the figure
        plt.close(fig)

        # while we're here, re-read the image and resize to 512x512 with a centered crop
        img = Image.open(outfile)
        # center crop
        center = (img.width/2, img.height/2)
        # resize to 512x512
        img = img.resize((512, 512), Image.ANTIALIAS)


        # left = center[0] - 256
        # top = center[1] - 256
        # right = center[0] + 256
        # bottom = center[1] + 256
        # img = img.crop((left, top, right, bottom))
        # #img = img.crop((0, 0, 512, 512))
        # img = img.resize((512, 512), Image.ANTIALIAS)
        img.save(outfile)

        # img = Image.open(outfile)
        # img = img.resize((512, 512), Image.ANTIALIAS)
        # img.save(outfile)
# Out:
# /var/folders/c5/8qdvlg4j6kg9_f9zbmjxykfw0000gn/T/ipykernel_21731/303141137.py:21: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   img = img.resize((512, 512), Image.ANTIALIAS)

# %%
# need to organize the files into directories

# create a directory for each letter
for character in string.ascii_letters:
    prefix = 'lower' if character.islower() else 'upper'    
    dir_letter = os.path.join(dir_final_png, prefix + '-' + character)
    try:
        os.mkdir(dir_letter)
    except OSError:
        print("{} already exists".format(dir_letter))


# move the files into the appropriate directories
for character in string.ascii_letters:
    prefix = 'lower' if character.islower() else 'upper'
    for font in fonts_to_use:
        src = os.path.join(dir_raw_png, '{}-{}-{}.png'.format(font, prefix, character))
        dst = os.path.join(dir_final_png, prefix + '-' + character, font + '.png')
        shutil.copyfile(src, dst)

# %%
# make a directory for each font
# for font in fonts_to_use:
#     dir_font = os.path.join(dir_final_png, font)
#     try:
#         os.mkdir(dir_font)
#     except OSError:
#         print("{} already exists".format(dir_font))
# copy the files into the appropriate directories
for font in fonts_to_use:
    # make a directory for each font
    dir_font = os.path.join(dir_final_class_png, font)
    try:
        os.mkdir(dir_font)
    except OSError:
        print("{} already exists".format(dir_font))
    for character in string.ascii_letters:
        prefix = 'lower' if character.islower() else 'upper'
        src = os.path.join(dir_raw_png, '{}-{}-{}.png'.format(font, prefix, character))
        dst = os.path.join(dir_final_class_png, font, '{}-{}-{}.png'.format(font, prefix, character))
        shutil.copyfile(src, dst)

# %% [markdown]
# # Create the concept list json

# %%
# create a concepts_list.json file
# this file will follow the format from here: https://github.com/ShivamShrirao/diffusers/blob/main/examples/dreambooth/concepts_list.json

# create a list of all the instances (each letter)
instances = sorted(os.listdir(dir_final_png)) # dir_final_png is the directory with all the letters
# create a list of all the classes (each font)
classes = sorted(os.listdir(dir_final_class_png)) # dir_final_class_png is the directory with all the fonts

concept_lists = []
# iterate over each instance and class
for instance in instances:
    for class_ in classes:
        # instance_token = re.split('[^a-zA-Z0-9]', instance)[0].replace('-', ' ')
        # general format for each instance
        concept_list = {
            "instance_prompt": "{} font".format(instance),
            "instance_data_dir": os.path.join(dir_final_png, instance),
            "class_prompt": "{} {}".format(class_, font_descriptions[class_]),
            "class_data_dir": os.path.join(dir_final_class_png, class_), # this is the same for all instances; all autodraw icons
        }
        concept_lists.append(concept_list)

# %%
len(concept_lists)
# Out:
# 728

# %%
# write to json file with pretty formatting
with open('res/concepts_list_fonts.json', 'w') as f:
    json.dump(concept_lists, f, indent=4)

# %%
# save to s3
import subprocess
subprocess.call(['aws', 's3', 'cp', 'res/fonts-matplotlib-class-final/', 
                 's3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/', 
                 '--recursive',
                 '--profile', 's3stablediffusion'])
subprocess.call(['aws', 's3', 'cp', 'res/fonts-matplotlib-final/', 
                 's3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/', 
                 '--recursive',
                 '--profile', 's3stablediffusion'])
# Out:
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-i.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-i.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-f.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-f.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-h.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-h.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-j.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-j.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-g.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-g.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-e.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-e.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-l.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-l.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-b.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-b.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-d.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-d.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-c.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-c.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-a.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-a.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-k.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-k.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-n.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-n.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-m.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-m.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-p.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-p.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-t.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-t.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-o.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-o.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-r.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-r.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-s.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-s.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-q.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-q.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-w.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-w.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-u.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-u.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-v.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-v.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-y.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-y.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-x.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-x.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-z.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-lower-z.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-E.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-E.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-B.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-B.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-D.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-D.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-F.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-F.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-A.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-A.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-H.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-H.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-I.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-I.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-C.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-C.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-G.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-G.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-L.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-L.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-J.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-J.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-P.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-P.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-N.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-N.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-K.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-K.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-M.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-M.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-O.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-O.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-T.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-T.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-S.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-S.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-R.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-R.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-Q.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-Q.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-U.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-U.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-W.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-W.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-V.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-V.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-Z.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-Z.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-Y.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-Y.png
# upload: res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-X.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Black/Arial Black-upper-X.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-a.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-a.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-d.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-d.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-c.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-c.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-f.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-f.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-b.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-b.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-e.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-e.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-h.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-h.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-j.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-j.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-i.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-i.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-g.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-g.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-l.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-l.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-k.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-k.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-m.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-m.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-n.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-n.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-p.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-p.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-o.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-o.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-t.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-t.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-q.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-q.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-r.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-r.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-u.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-u.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-s.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-s.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-v.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-v.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-x.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-x.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-w.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-w.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-B.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-B.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-z.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-z.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-A.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-A.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-D.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-D.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-E.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-E.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-y.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-lower-y.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-C.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-C.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-I.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-I.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-F.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-F.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-H.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-H.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-L.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-L.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-G.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-G.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-K.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-K.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-J.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-J.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-M.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-M.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-R.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-R.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-P.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-P.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-N.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-N.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-O.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-O.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-T.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-T.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-Q.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-Q.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-S.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-S.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-U.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-U.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-V.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-V.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-Z.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-Z.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-X.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-X.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-Y.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-Y.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-b.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-b.png
# upload: res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-W.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Narrow/Arial Narrow-upper-W.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-a.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-a.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-f.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-f.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-d.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-d.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-c.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-c.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-h.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-h.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-k.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-k.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-j.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-j.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-i.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-i.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-l.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-l.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-g.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-g.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-n.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-n.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-e.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-e.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-o.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-o.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-m.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-m.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-p.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-p.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-r.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-r.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-s.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-s.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-t.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-t.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-q.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-q.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-u.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-u.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-v.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-v.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-x.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-x.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-z.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-z.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-y.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-y.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-B.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-B.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-w.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-lower-w.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-E.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-E.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-A.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-A.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-C.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-C.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-D.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-D.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-F.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-F.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-H.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-H.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-G.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-G.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-I.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-I.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-K.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-K.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-M.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-M.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-L.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-L.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-J.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-J.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-N.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-N.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-O.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-O.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-R.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-R.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-P.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-P.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-T.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-T.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-S.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-S.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-U.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-U.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-Q.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-Q.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-V.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-V.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-W.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-W.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-Y.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-Y.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-X.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-X.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-lower-c.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-lower-c.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-lower-a.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-lower-a.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-lower-b.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-lower-b.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-lower-d.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-lower-d.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-lower-f.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-lower-f.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-lower-e.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-lower-e.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-lower-h.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-lower-h.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-lower-g.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-lower-g.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-lower-j.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-lower-j.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-lower-k.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-lower-k.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-lower-l.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-lower-l.png
# upload: res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-Z.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial Unicode MS/Arial Unicode MS-upper-Z.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-lower-i.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-lower-i.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-lower-m.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-lower-m.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-lower-n.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-lower-n.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-lower-p.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-lower-p.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-lower-o.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-lower-o.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-lower-s.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-lower-s.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-lower-u.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-lower-u.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-lower-t.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-lower-t.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-lower-v.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-lower-v.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-lower-x.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-lower-x.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-lower-q.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-lower-q.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-lower-w.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-lower-w.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-lower-r.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-lower-r.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-lower-z.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-lower-z.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-upper-A.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-upper-A.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-lower-y.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-lower-y.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-upper-D.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-upper-D.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-upper-B.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-upper-B.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-upper-G.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-upper-G.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-upper-E.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-upper-E.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-upper-C.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-upper-C.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-upper-H.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-upper-H.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-upper-I.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-upper-I.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-upper-J.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-upper-J.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-upper-L.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-upper-L.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-upper-M.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-upper-M.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-upper-K.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-upper-K.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-upper-N.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-upper-N.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-upper-F.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-upper-F.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-upper-O.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-upper-O.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-upper-P.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-upper-P.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-upper-T.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-upper-T.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-upper-Q.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-upper-Q.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-upper-R.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-upper-R.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-upper-S.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-upper-S.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-upper-U.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-upper-U.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-upper-Y.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-upper-Y.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-upper-X.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-upper-X.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-upper-V.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-upper-V.png
# upload: res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-a.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-a.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-upper-W.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-upper-W.png
# upload: res/fonts-matplotlib-class-final/Arial/Arial-upper-Z.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Arial/Arial-upper-Z.png
# upload: res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-d.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-d.png
# upload: res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-c.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-c.png
# upload: res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-e.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-e.png
# upload: res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-b.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-b.png
# upload: res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-f.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-f.png
# upload: res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-g.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-g.png
# upload: res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-h.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-h.png
# upload: res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-j.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-j.png
# upload: res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-i.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-i.png
# upload: res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-m.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-m.png
# upload: res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-k.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-k.png
# upload: res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-o.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-o.png
# upload: res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-n.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-n.png
# upload: res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-l.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-l.png
# upload: res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-q.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-q.png
# upload: res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-u.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-u.png
# upload: res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-t.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-t.png
# upload: res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-r.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-r.png
# upload: res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-p.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-p.png
# upload: res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-s.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-s.png
# upload: res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-w.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-w.png
# upload: res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-v.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-v.png
# upload: res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-x.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-x.png
# upload: res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-y.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-lower-y.png
# upload: res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-upper-E.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-upper-E.png
# upload: res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-upper-C.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-class-final/Brush Script MT/Brush Script MT-upper-C.png
# ...
# upload: res/fonts-matplotlib-final/upper-S/Zapfino.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-S/Zapfino.png
# upload: res/fonts-matplotlib-final/upper-T/Arial.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-T/Arial.png
# upload: res/fonts-matplotlib-final/upper-S/Rockwell.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-S/Rockwell.png
# upload: res/fonts-matplotlib-final/upper-S/Menlo.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-S/Menlo.png
# upload: res/fonts-matplotlib-final/upper-T/Didot.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-T/Didot.png
# upload: res/fonts-matplotlib-final/upper-T/Comic Sans MS.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-T/Comic Sans MS.png
# upload: res/fonts-matplotlib-final/upper-T/Helvetica Neue.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-T/Helvetica Neue.png
# upload: res/fonts-matplotlib-final/upper-T/Brush Script MT.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-T/Brush Script MT.png
# upload: res/fonts-matplotlib-final/upper-T/Gill Sans.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-T/Gill Sans.png
# upload: res/fonts-matplotlib-final/upper-T/Futura.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-T/Futura.png
# upload: res/fonts-matplotlib-final/upper-T/Menlo.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-T/Menlo.png
# upload: res/fonts-matplotlib-final/upper-T/Impact.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-T/Impact.png
# upload: res/fonts-matplotlib-final/upper-T/Rockwell.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-T/Rockwell.png
# upload: res/fonts-matplotlib-final/upper-T/Zapfino.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-T/Zapfino.png
# upload: res/fonts-matplotlib-final/upper-U/Arial Black.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-U/Arial Black.png
# upload: res/fonts-matplotlib-final/upper-U/Arial Narrow.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-U/Arial Narrow.png
# upload: res/fonts-matplotlib-final/upper-U/Brush Script MT.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-U/Brush Script MT.png
# upload: res/fonts-matplotlib-final/upper-U/Arial Unicode MS.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-U/Arial Unicode MS.png
# upload: res/fonts-matplotlib-final/upper-U/Arial.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-U/Arial.png
# upload: res/fonts-matplotlib-final/upper-U/Comic Sans MS.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-U/Comic Sans MS.png
# upload: res/fonts-matplotlib-final/upper-U/Didot.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-U/Didot.png
# upload: res/fonts-matplotlib-final/upper-U/Futura.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-U/Futura.png
# upload: res/fonts-matplotlib-final/upper-U/Impact.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-U/Impact.png
# upload: res/fonts-matplotlib-final/upper-U/Menlo.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-U/Menlo.png
# upload: res/fonts-matplotlib-final/upper-U/Gill Sans.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-U/Gill Sans.png
# upload: res/fonts-matplotlib-final/upper-U/Helvetica Neue.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-U/Helvetica Neue.png
# upload: res/fonts-matplotlib-final/upper-V/Arial Black.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-V/Arial Black.png
# upload: res/fonts-matplotlib-final/upper-U/Zapfino.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-U/Zapfino.png
# upload: res/fonts-matplotlib-final/upper-V/Arial Unicode MS.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-V/Arial Unicode MS.png
# upload: res/fonts-matplotlib-final/upper-U/Rockwell.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-U/Rockwell.png
# upload: res/fonts-matplotlib-final/upper-V/Arial Narrow.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-V/Arial Narrow.png
# upload: res/fonts-matplotlib-final/upper-V/Comic Sans MS.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-V/Comic Sans MS.png
# upload: res/fonts-matplotlib-final/upper-V/Arial.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-V/Arial.png
# upload: res/fonts-matplotlib-final/upper-V/Futura.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-V/Futura.png
# upload: res/fonts-matplotlib-final/upper-V/Didot.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-V/Didot.png
# upload: res/fonts-matplotlib-final/upper-V/Brush Script MT.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-V/Brush Script MT.png
# upload: res/fonts-matplotlib-final/upper-V/Gill Sans.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-V/Gill Sans.png
# upload: res/fonts-matplotlib-final/upper-V/Impact.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-V/Impact.png
# upload: res/fonts-matplotlib-final/upper-V/Helvetica Neue.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-V/Helvetica Neue.png
# upload: res/fonts-matplotlib-final/upper-V/Menlo.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-V/Menlo.png
# upload: res/fonts-matplotlib-final/upper-V/Rockwell.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-V/Rockwell.png
# upload: res/fonts-matplotlib-final/upper-W/Arial Narrow.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-W/Arial Narrow.png
# upload: res/fonts-matplotlib-final/upper-W/Arial Unicode MS.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-W/Arial Unicode MS.png
# upload: res/fonts-matplotlib-final/upper-W/Arial.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-W/Arial.png
# upload: res/fonts-matplotlib-final/upper-W/Arial Black.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-W/Arial Black.png
# upload: res/fonts-matplotlib-final/upper-V/Zapfino.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-V/Zapfino.png
# upload: res/fonts-matplotlib-final/upper-W/Brush Script MT.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-W/Brush Script MT.png
# upload: res/fonts-matplotlib-final/upper-W/Comic Sans MS.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-W/Comic Sans MS.png
# upload: res/fonts-matplotlib-final/upper-W/Didot.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-W/Didot.png
# upload: res/fonts-matplotlib-final/upper-W/Impact.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-W/Impact.png
# upload: res/fonts-matplotlib-final/upper-W/Futura.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-W/Futura.png
# upload: res/fonts-matplotlib-final/upper-W/Zapfino.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-W/Zapfino.png
# upload: res/fonts-matplotlib-final/upper-W/Rockwell.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-W/Rockwell.png
# upload: res/fonts-matplotlib-final/upper-W/Menlo.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-W/Menlo.png
# upload: res/fonts-matplotlib-final/upper-W/Gill Sans.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-W/Gill Sans.png
# upload: res/fonts-matplotlib-final/upper-W/Helvetica Neue.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-W/Helvetica Neue.png
# upload: res/fonts-matplotlib-final/upper-X/Arial Narrow.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-X/Arial Narrow.png
# upload: res/fonts-matplotlib-final/upper-X/Arial Unicode MS.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-X/Arial Unicode MS.png
# upload: res/fonts-matplotlib-final/upper-X/Arial Black.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-X/Arial Black.png
# upload: res/fonts-matplotlib-final/upper-X/Comic Sans MS.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-X/Comic Sans MS.png
# upload: res/fonts-matplotlib-final/upper-X/Didot.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-X/Didot.png
# upload: res/fonts-matplotlib-final/upper-X/Arial.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-X/Arial.png
# upload: res/fonts-matplotlib-final/upper-X/Futura.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-X/Futura.png
# upload: res/fonts-matplotlib-final/upper-X/Brush Script MT.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-X/Brush Script MT.png
# upload: res/fonts-matplotlib-final/upper-X/Helvetica Neue.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-X/Helvetica Neue.png
# upload: res/fonts-matplotlib-final/upper-X/Gill Sans.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-X/Gill Sans.png
# upload: res/fonts-matplotlib-final/upper-X/Rockwell.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-X/Rockwell.png
# upload: res/fonts-matplotlib-final/upper-X/Menlo.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-X/Menlo.png
# upload: res/fonts-matplotlib-final/upper-X/Impact.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-X/Impact.png
# upload: res/fonts-matplotlib-final/upper-Y/Arial Black.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-Y/Arial Black.png
# upload: res/fonts-matplotlib-final/upper-Y/Arial Narrow.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-Y/Arial Narrow.png
# upload: res/fonts-matplotlib-final/upper-Y/Arial Unicode MS.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-Y/Arial Unicode MS.png
# upload: res/fonts-matplotlib-final/upper-X/Zapfino.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-X/Zapfino.png
# upload: res/fonts-matplotlib-final/upper-Y/Comic Sans MS.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-Y/Comic Sans MS.png
# upload: res/fonts-matplotlib-final/upper-Y/Arial.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-Y/Arial.png
# upload: res/fonts-matplotlib-final/upper-Y/Brush Script MT.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-Y/Brush Script MT.png
# upload: res/fonts-matplotlib-final/upper-Y/Gill Sans.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-Y/Gill Sans.png
# upload: res/fonts-matplotlib-final/upper-Y/Futura.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-Y/Futura.png
# upload: res/fonts-matplotlib-final/upper-Y/Didot.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-Y/Didot.png
# upload: res/fonts-matplotlib-final/upper-Y/Helvetica Neue.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-Y/Helvetica Neue.png
# upload: res/fonts-matplotlib-final/upper-Y/Impact.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-Y/Impact.png
# upload: res/fonts-matplotlib-final/upper-Y/Zapfino.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-Y/Zapfino.png
# upload: res/fonts-matplotlib-final/upper-Y/Rockwell.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-Y/Rockwell.png
# upload: res/fonts-matplotlib-final/upper-Z/Arial Black.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-Z/Arial Black.png
# upload: res/fonts-matplotlib-final/upper-Z/Arial Narrow.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-Z/Arial Narrow.png
# upload: res/fonts-matplotlib-final/upper-Y/Menlo.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-Y/Menlo.png
# upload: res/fonts-matplotlib-final/upper-Z/Arial Unicode MS.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-Z/Arial Unicode MS.png
# upload: res/fonts-matplotlib-final/upper-Z/Arial.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-Z/Arial.png
# upload: res/fonts-matplotlib-final/upper-Z/Comic Sans MS.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-Z/Comic Sans MS.png
# upload: res/fonts-matplotlib-final/upper-Z/Brush Script MT.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-Z/Brush Script MT.png
# upload: res/fonts-matplotlib-final/upper-Z/Futura.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-Z/Futura.png
# upload: res/fonts-matplotlib-final/upper-Z/Impact.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-Z/Impact.png
# upload: res/fonts-matplotlib-final/upper-Z/Helvetica Neue.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-Z/Helvetica Neue.png
# upload: res/fonts-matplotlib-final/upper-Z/Menlo.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-Z/Menlo.png
# upload: res/fonts-matplotlib-final/upper-Z/Gill Sans.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-Z/Gill Sans.png
# upload: res/fonts-matplotlib-final/upper-Z/Didot.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-Z/Didot.png
# upload: res/fonts-matplotlib-final/upper-Z/Zapfino.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-Z/Zapfino.png
# upload: res/fonts-matplotlib-final/upper-Z/Rockwell.png to s3://379552636459-stable-diffusion/experiment9-fonts/res/fonts-matplotlib-final/upper-Z/Rockwell.png
# 0
